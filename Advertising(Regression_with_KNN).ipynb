# %% [markdown]
# <a href="https://colab.research.google.com/github/ehsankarami1358/ehsan/blob/main/Advertising(Regression_with_KNN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
df=pd.read_csv('Advertising.csv')
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.shape
# Out:
# (200, 5)

# %%
col=['TV','Radio','Newspaper']
x=df[['TV','Radio','Newspaper']].values
y=df[['Sales']].values

# %%
for m in col:
    plt.scatter(x=df[m],y=df[['Sales']])
    plt.xlabel('features')
    plt.ylabel('Sales')
    plt.show()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
fig,ax=plt.subplots(figsize=(10,10))
k_list=np.arange(1,80,1)
knn_dict={}
for i in k_list:
    knn=KNeighborsRegressor(n_neighbors=i)
    modek_knn=knn.fit(x_train,y_train)
    y_knn_pred=knn.predict(x_test)
    mse=mean_squared_error(y_test,y_knn_pred)
    knn_dict[i]=mse
    ax.plot(np.array(list(knn_dict.keys())).astype(float),np.array(list(knn_dict.values())).astype(float))
    ax.set_xlabel('k')
    ax.set_ylabel('MSE')

# %%
mean_squared_error(y_test,y_knn_pred)
# Out:
# 12.878259734016984
